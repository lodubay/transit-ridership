# %% [markdown]
# # Summary Time-Series Data Exploration

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def import_training_data(filename):
    return pd.read_csv('../data/train/%s' % filename, index_col='UACE Code', dtype={'UACE Code': str})

# %%
upt_data = import_training_data('UPT_percap.csv')
# upt_data.replace(0, np.nan, inplace=True)
upt_data
# Out:
#                 1991       1992       1993       1994       1995       1996  \
# UACE Code
# 00766      10.427298  10.941214  10.637745   9.530366   8.907610   9.609776
# 00901      13.745799  14.468430  14.478371  13.491958  13.027350  14.353281
# 01171      13.577808  13.176022  13.125281  12.758613  12.411851  12.496826
# 01495       8.560515   8.514670   8.317389   7.878184   7.818438   6.927107
# 01792      11.627064  10.798976  10.308562   9.755192   9.275082   9.645244
# ...              ...        ...        ...        ...        ...        ...
# 96670      16.033447  16.483599  16.352324  15.039235  14.679994  12.934850
# 97291      13.142323  12.963643  11.381410  11.230226  11.063748  12.570981
# 97507      14.790547  16.220865  16.173934  14.338512  11.965593  10.439422
# 97831       3.485334   3.508939   3.122193   3.141723   3.163442   2.707432
# 98020            NaN        NaN        NaN        NaN        NaN        NaN
#
# ...

# %%
years = [int(y) for y in upt_data.columns]

# %%
fig, ax = plt.subplots()
for i, row in upt_data.iterrows():
    ax.plot(years, row, linestyle='-', color='k', alpha=0.2)
ax.set_yscale('log')
ax.set_xlabel('Year')
ax.set_ylabel('UPT Per Capita')
plt.show()

# %%
pmt_data = import_training_data('PMT_percap.csv')
pmt_data
# Out:
#                 1991       1992       1993       1994       1995       1996  \
# UACE Code
# 00766      32.985644  36.494020  40.349822  30.377990  32.173753  32.619910
# 00901      36.472670  37.526874  39.564562  36.369210  36.557601  39.675234
# 01171      44.756195  43.431800  43.246081  42.037959  40.895425  42.393197
# 01495      33.920469  33.776228  31.694371  30.031525  30.088056  28.018061
# 01792      37.982793  35.275771  33.517223  31.818006  30.241329  31.071234
# ...              ...        ...        ...        ...        ...        ...
# 96670      61.825690  45.732716  73.389236  65.536874  74.567091  65.495419
# 97291      36.700113  36.094119  30.387142  30.016499  29.569149  34.632860
# 97507      44.923759  51.588972  51.691602  44.322401  28.026384  22.926466
# 97831      12.460855  12.545246   7.883132   7.933865   7.988711   7.717994
# 98020            NaN        NaN        NaN        NaN        NaN        NaN
#
# ...

# %%
fare_data = import_training_data('FARES_infladj_percap.csv')
fare_data
# Out:
#            1991  1992  1993  1994  1995  1996  1997  1998  1999  2000  ...  \
# UACE Code                                                              ...
# 00766       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 00901       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 01171       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 01495       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 01792       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# ...         ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# 96670       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 97291       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 97507       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 97831       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# ...

# %%
vrm_data = pd.read_csv('../data/train/VRM_percap.csv', index_col='UACE Code', dtype={'UACE Code': str})
vrm_data
# Out:
#                1991      1992      1993       1994      1995       1996  \
# UACE Code
# 00766      6.968202  7.931880  8.055881   8.160589  8.947868  10.102051
# 00901      5.311614  5.241548  5.500845   5.583001  5.688954   5.899599
# 01171      9.362347  9.934404  9.590745   9.673382  8.911596   9.044317
# 01495      5.270398  5.393823  5.555011   5.848505  6.455424   6.785846
# 01792      6.491096  6.523974  6.623504   6.476283  6.686798   6.796316
# ...             ...       ...       ...        ...       ...        ...
# 96670      8.828131  8.789962  8.720601   8.523605  9.314387   8.605786
# 97291      8.391934  8.629792  8.515630   8.637532  8.790231   8.183094
# 97507      7.338676  8.212538  9.101787  10.487094  7.560738   6.404587
aN        NaN        NaN        NaN        NaN
#
# ...

# %%
fig, ax = plt.subplots()
for i, row in opexp_total.iterrows():
    ax.plot(years, row, linestyle='-', color='k', alpha=0.2)
ax.set_yscale('log')
ax.set_xlabel('Year')
ax.set_ylabel('Total Operating Expenses (2019 Dollars)')
plt.show()

# %%
opfund_frac = pd.read_csv('../data/train/OpFund_frac.csv', index_col='UACE Code', dtype={'UACE Code': str})
opfund_frac
# Out:
#                1991      1992      1993      1994      1995      1996  \
# UACE Code
# 00766      0.928218  0.807065  0.836136  0.882200  0.953968  0.907309
# 00901      0.917610  0.831072  0.818472  0.955666  0.975851  0.792944
# 01171      0.966535  1.000000  0.971983  0.997733  0.987024  0.901056
# 01495      0.951101  0.862354  0.884881  0.855173  0.886924  0.748597
# 01792      0.983519  0.900824  0.497112  0.962896  0.878453  0.914435
# ...             ...       ...       ...       ...       ...       ...
# 96670      0.958411  0.847466  0.829795  0.802495  0.788882  0.568057
# 97291      0.923543  0.916204  0.942164  0.854540  0.915551  0.575625
# 97507      0.741680  0.741367  0.564545  0.706234  0.986517  0.984853
# 97831      0.959525  0.953510  0.907352  0.836853  0.929875  0.946217
# 98020           NaN       NaN       NaN       NaN       NaN       NaN
#
#                1997      1998      1999      2000  ...      2009      2010  \
# ...

# %%
fund_total = pd.read_csv('../data/train/TotalFund_infladj_percap.csv', index_col='UACE Code', dtype={'UACE Code': str})
fund_total
# Out:
#                 1991        1992        1993        1994       1995  \
# UACE Code
# 00766      51.842412   63.605519   65.070749   71.834562  60.454239
# 00901      23.200093   23.951498   23.903050   20.850101  25.740340
# 01171      53.389767   50.635087   52.364223   53.518037  54.100489
# 01495      37.481882   39.565031   37.007765   37.597805  35.461563
# 01792      42.737247   49.085815   91.113424   45.078268  47.547913
# ...              ...         ...         ...         ...        ...
# 96670      37.847561   42.966290   45.005438   47.367949  47.556884
# 97291      66.635150   67.529236   73.476699   65.276051  58.567828
# 97507      81.565847  104.383321  122.104798  100.283954  66.199616
# 97831      21.706035   19.090122   18.852838   21.468416  17.366194
# 98020            NaN         NaN         NaN         NaN        NaN
#
#                 1996       1997        1998        1999       2000  ...  \
# ...

# %%
fig, ax = plt.subplots()
for i, row in opfund_frac.iterrows():
    ax.plot(years, row, linestyle='-', color='k', alpha=0.2)
ax.set_xlabel('Year')
ax.set_ylabel('Fraction of total funding for operations')
plt.show()

# %%
city_info = pd.read_csv('../data/Cities.csv', index_col='UACE Code', dtype={'UACE Code': str})
columbus_code = city_info[city_info['Primary UZA Name'] == 'Columbus, OH'].index[0]
portland_code = city_info[city_info['Primary UZA Name'] == 'Portland, OR--WA'].index[0]

# %%
fig, ax = plt.subplots()
ax.plot(years, upt_data.loc[portland_code])
ax.set_xlabel('Year')
ax.set_ylabel('UPT per capita')
ax.set_title(city_info.loc[portland_code, 'Primary UZA Name'].iloc[0])
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(years, pmt_data.loc[portland_code])
ax.set_xlabel('Year')
ax.set_ylabel('PMT per capita')
ax.set_title(city_info.loc[portland_code, 'Primary UZA Name'].iloc[0])
plt.show()

# %% [markdown]
# There is some trend with time, but it's not linear or consistent across the full time range. I think either a naive model or a drift model makes sense for the baseline.

# %%
fig, ax = plt.subplots()
ax.plot(years, fare_data.loc[portland_code])
ax.set_xlabel('Year')
ax.set_ylabel('Fare revenue per capita (2019 dollars)')
ax.set_title(city_info.loc[portland_code, 'Primary UZA Name'].iloc[0])
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(years, vrm_data.loc[portland_code])
ax.set_xlabel('Year')
ax.set_ylabel('VRM per capita')
ax.set_title(city_info.loc[portland_code, 'Primary UZA Name'].iloc[0])
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(upt_data.loc[portland_code], vrm_data.loc[portland_code], 'o')
ax.set_xlabel('UPT per capita')
ax.set_ylabel('VRM per capita')
ax.set_title(city_info.loc[portland_code, 'Primary UZA Name'].iloc[0])
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(years, vrh_data.loc[portland_code])
ax.set_xlabel('Year')
ax.set_ylabel('VRH per capita')
ax.set_title(city_info.loc[portland_code, 'Primary UZA Name'].iloc[0])
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(upt_data.loc[portland_code], vrh_data.loc[portland_code], 'o')
ax.set_xlabel('UPT per capita')
ax.set_ylabel('VRH per capita')
ax.set_title(city_info.loc[portland_code, 'Primary UZA Name'].iloc[0])
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(years, voms_data.loc[portland_code])
ax.set_xlabel('Year')
ax.set_ylabel('VOMS per capita')
ax.set_title(city_info.loc[portland_code, 'Primary UZA Name'].iloc[0])
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(years, opexp_total.loc[portland_code])
ax.set_xlabel('Year')
ax.set_ylabel('Operational Expenses per capita (2019 dollars)')
ax.set_title(city_info.loc[portland_code, 'Primary UZA Name'].iloc[0])
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(years, opfund_frac.loc[portland_code])
ax.set_xlabel('Year')
ax.set_ylabel('Fraction of funding for operations')
ax.set_title(city_info.loc[portland_code, 'Primary UZA Name'].iloc[0])
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(years, fund_total.loc[portland_code])
ax.set_xlabel('Year')
ax.set_ylabel('Total funding per capita (2019 dollars)')
ax.set_title(city_info.loc[portland_code, 'Primary UZA Name'].iloc[0])
plt.show()

# %% [markdown]
# ## All data for one city

# %%
def combine_city_data(city_code, dfs, names):
    """
    Generate a single DataFrame with data from all years for one city.
    """
    data_rows = [df.loc[city_code] for df in dfs]
    all_data = pd.concat(data_rows, axis=1)
    all_data.columns = names
    all_data.index.name = 'Year'
    return all_data

# %%
# Import all dataframes
names = ['UPT_percap', 'PMT_percap', 'VRM_percap', 'VRH_percap', 'VOMS_percap']
dfs = [import_training_data('%s.csv' % name) for name in names]
combine_city_data(portland_code, dfs, names)
# Out:
#       UPT_percap  PMT_percap  VRM_percap  VRH_percap  VOMS_percap
# Year
# 1991   46.468933  177.382379   18.597194    1.368355     0.000459
# 1992   47.568235  174.137526   18.585086    1.365053     0.000447
# 1993   46.572931  177.693348   19.029848    1.397079     0.000473
# 1994   48.273455  199.086679   19.801321    1.453492     0.000496
# 1995   48.162249  190.554717   19.947680    1.483525     0.000512
# 1996   52.481126  207.605107   20.719402    1.541540     0.000508
# 1997   52.060935  217.836508   21.331938    1.539917     0.000525
# 1998   56.944168  226.436783   21.936094    1.626271     0.000555
# 1999   58.088500  248.565659   23.809001    1.736862     0.000602
# 2000   59.193234  248.534160   24.016763    1.761257     0.000574
# 2001   60.483737  249.323610   23.487054    1.737680     0.000576
# 2002   65.300532  273.119840   24.253453    1.781208     0.000578
# 2003   63.514424  272.248694   24.532311    1.779980     0.000577
# ...
