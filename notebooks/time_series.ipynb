# %% [markdown]
# # Summary Time-Series Data Exploration

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
pop_data = pd.read_csv('../data/UZA_population.csv', index_col='UACE Code', dtype={'UACE Code': str})
pop_data
# Out:
#                                            Name     1991     1992     1993  \
# UACE Code
# 80389                       Seattle--Tacoma, WA  2399735  2434454  2469173
# 83764                               Spokane, WA   287167   292466   297765
# 97507                                Yakima, WA    97769    99441   101113
# 28117                                Eugene, OR   203014   205351   207688
# 71317                          Portland, OR--WA  1343054  1369730  1396406
# ...                                         ...      ...      ...      ...
# 19504                 Concord--Walnut Creek, CA   495614   501948   508283
# 41347      Indio--Palm Desert--Palm Springs, CA   173204   182276   191349
# 79417                           Santa Maria, CA   111162   112177   113192
# 90946                               Visalia, CA    30575    40516    50457
# 28657                             Fairfield, CA    93332    95456    97580
#
# ...

# %%
upt_data = pd.read_csv('../data/UPT.csv', index_col='NTD ID', dtype={'NTD ID': str, 'UACE Code': str})
upt_data
# Out:
#                                               Agency Name            City  \
# NTD ID
# 00001        King County (KCM) - Metro Transit Department         Seattle
# 00003   Pierce County Transportation Benefit Area Auth...        Lakewood
# 00005                                City of Everett (ET)         Everett
# 00023                               City of Seattle (SMS)         Seattle
# 00028                                    County of Pierce          Tacoma
# ...                                                   ...             ...
# 90078      Central Contra Costa Transit Authority (CCCTA)         Concord
# 90079                              SunLine Transit Agency  Thousand Palms
# 90087                          City of Santa Maria (SMRT)     Santa Maria
# 90091              City of Visalia (VT) - Transportation          Visalia
# 90092   City of Fairfield, California - Transportation...       Fairfield
#
#        State                      Primary UZA Name UACE Code  \
# ...

# %%
year_cols = [str(y) for y in range(1991, 2020)]
years = list(range(1991, 2020))
agency_info = upt_data[[c for c in upt_data.columns if not c in year_cols]].copy()
agency_info
# Out:
#                                               Agency Name            City  \
# NTD ID
# 00001        King County (KCM) - Metro Transit Department         Seattle
# 00003   Pierce County Transportation Benefit Area Auth...        Lakewood
# 00005                                City of Everett (ET)         Everett
# 00023                               City of Seattle (SMS)         Seattle
# 00028                                    County of Pierce          Tacoma
# ...                                                   ...             ...
# 90078      Central Contra Costa Transit Authority (CCCTA)         Concord
# 90079                              SunLine Transit Agency  Thousand Palms
# 90087                          City of Santa Maria (SMRT)     Santa Maria
# 90091              City of Visalia (VT) - Transportation          Visalia
# 90092   City of Fairfield, California - Transportation...       Fairfield
#
#        State                      Primary UZA Name UACE Code  \
# ...

# %%
upt_per_capita = upt_data.set_index('UACE Code')[year_cols] / pop_data[year_cols].loc[upt_data['UACE Code']]
upt_per_capita.set_index(upt_data.index, inplace=True)
upt_per_capita
# Out:
#              1991       1992       1993       1994       1995       1996  \
# NTD ID
# 00001   33.374216  34.378433  33.902885  32.974316  32.893324  35.181616
# 00003    4.193593   4.299509   4.314477   5.121780   4.833671   4.903715
# 00005    0.756695   0.772406   0.790376   0.819243   0.698140   0.637067
# 00023    0.926172   0.895909   0.858177   0.846409   0.902436   0.986128
# 00028    0.047995   0.051612   0.054404   0.056247   0.062974   0.062702
# ...           ...        ...        ...        ...        ...        ...
# 90078    8.686748   8.602200   8.167324   9.032667   7.812693   9.662052
# 90079   15.419794  16.889541  15.825194  14.761138  12.779612  13.126831
# 90087    2.664166   2.552083   3.080907   3.053526   3.303623   3.252458
# 90091   18.415470  16.249531  14.509919  13.230902  13.355123  13.900648
# 90092    3.787147   3.702879   6.215321   7.169624   7.217693   7.597868
#
#              1997       1998       1999       2000  ...       2010       2011  \
# ...

# %%
fig, ax = plt.subplots()
for i, row in upt_per_capita.iterrows():
    ax.plot(years, row, linestyle='-', color='k', alpha=0.2)
ax.set_yscale('log')
ax.set_xlabel('Year')
ax.set_ylabel('UPT Per Capita')
plt.show()

# %%
upt_per_capita[upt_per_capita['2019'] > 100]
# Out:
#               1991        1992        1993       1994        1995        1996  \
# NTD ID
# 20008   114.531953  116.607015  103.301597  109.61004  108.066412  113.232207
#
#               1997        1998        1999        2000  ...      2014  \
# NTD ID                                                  ...
# 20008   125.625349  125.815504  136.895148  140.449101  ...  188.7601
#
#               2015        2016        2017        2018       2019       2020  \
# NTD ID
# 20008   182.411354  182.389606  180.101603  175.317749  178.64028  79.297823
#
#              2021        2022        2023
# NTD ID
# 20008   88.430811  115.782643  133.272759
#
# [1 rows x 33 columns]
